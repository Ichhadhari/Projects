# %%
# !pip install pandas

# !pip install lxml


#only for requirements
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

##############
scraper=pd.read_html('https://dopt.gov.in/posting-of-ias-officers-list')
print(scraper)
# Out:
# [                        Name         DOB             Cadre  \
# 0                ADITYA NEGI  26/05/1986  Himachal Pradesh
# 1         Aditya Kumar Anand  10/05/1986         Jharkhand
# 2         ADWAIT KUMAR SINGH  07/10/1988         Telangana
# 3                 AJAY KUMAR  26/10/1983           Haryana
# 4               AJEET VASANT  20/01/1987       Chhatisgarh
# ..                       ...         ...               ...
# 156         VISHESH SARANGAL  19/12/1984            Punjab
# 157             VINEET KUMAR  13/10/1984       Uttaranchal
# 158           YOGENDRA SINGH  10/04/1987             Bihar
# 159  YOGESH BABANRAO NIRGUDE  04/02/1984           Gujarat
# 160            ZEESHAN QAMER  04/12/1980         Jharkhand
#
#                      Address                             Email Address  \
# 0    23/7-06(D), CWG Village             aditya[dot]negi[at]nic[dot]in
# 1         A-607, Curzon Road   adityak[dot]anand[at]ias[dot]nic[dot]in
# ...

# %%
data=scraper[0]
data
# Out:
#                         Name         DOB             Cadre  \
# 0                ADITYA NEGI  26/05/1986  Himachal Pradesh
# 1         Aditya Kumar Anand  10/05/1986         Jharkhand
# 2         ADWAIT KUMAR SINGH  07/10/1988         Telangana
# 3                 AJAY KUMAR  26/10/1983           Haryana
# 4               AJEET VASANT  20/01/1987       Chhatisgarh
# ..                       ...         ...               ...
# 156         VISHESH SARANGAL  19/12/1984            Punjab
# 157             VINEET KUMAR  13/10/1984       Uttaranchal
# 158           YOGENDRA SINGH  10/04/1987             Bihar
# 159  YOGESH BABANRAO NIRGUDE  04/02/1984           Gujarat
# 160            ZEESHAN QAMER  04/12/1980         Jharkhand
#
#                      Address                             Email Address  \
# 0    23/7-06(D), CWG Village             aditya[dot]negi[at]nic[dot]in
# 1         A-607, Curzon Road   adityak[dot]anand[at]ias[dot]nic[dot]in
# ...

# %%
##########  data cleaning on data cleaning section ##################
data.to_excel('IAS_info.xlsx')
