# %%
# !pip install MechanicalSoup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting MechanicalSoup
#   Downloading MechanicalSoup-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from MechanicalSoup) (4.9.1)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from MechanicalSoup) (2.23.0)
# Collecting beautifulsoup4>=4.7
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 10.0 MB/s
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->MechanicalSoup) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->MechanicalSoup) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->MechanicalSoup) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->MechanicalSoup) (2022.9.24)
# Installing collected packages: soupsieve, beautifulsoup4, MechanicalSoup
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed MechanicalSoup-1.2.0 beautifulsoup4-4.11.1 soupsieve-2.3.2.post1

# %%
! pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=98fc9d4ef115cb8366706483d845de52273a082c63c620511214bee15278fb84
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %% [markdown]
# # Navigate to Google Images

# %%
import mechanicalsoup

browser = mechanicalsoup.StatefulBrowser()
url = "https://www.google.com/imghp?hl=en"

browser.open(url)
print(browser.get_url())
# Out:
# https://www.google.com/imghp?hl=en

# %% [markdown]
# # Type a search term and click "search"

# %%
#get HTML
browser.get_current_page()

#target the search input
browser.select_form()
browser.get_current_form().print_summary()

#search for a term
search_term = 'dog'
browser["q"] = search_term 

#submit/"click" search
browser.launch_browser()
response = browser.submit_selected()

print('new url:', browser.get_url())
print('my response:\n', response.text[:500])
# Out:
# <input name="tbm" type="hidden" value="isch"/>
# <input name="ie" type="hidden" value="ISO-8859-1"/>
# <input name="hl" type="hidden" value="en"/>
# <input name="source" type="hidden" value="hp"/>
# <input name="biw" type="hidden"/>
# <input name="bih" type="hidden"/>
# <input autocomplete="off" class="lst" maxlength="2048" name="q" size="57" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000" title="Search Images" value=""/>
# <input class="lsb" name="btnG" type="submit" value="Search Images"/>
# <input id="gbv" name="gbv" type="hidden" value="1"/>
# new url: https://www.google.com/search?tbm=isch&ie=ISO-8859-1&hl=en&source=hp&biw=&bih=&q=dog&btnG=Search+Images&gbv=1
# my response:
#  <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>dog - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;

# %%
new_url=browser.get_url()
browser.open(new_url)


##### 
page=browser.get_current_page()
all_image=page.find_all('img')


###

image_source=[]

for image in all_image:
  image=image.get('src')
  image_source.append(image)


image_source
# Out:
# ['/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFhiWD9Bp7SXM_HP8_TlWzuvs7MF-mPYa7LV0h8Q7Gy6ii7TjuJikwKWaZTOE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDvO0ky2gO_nenMQVae5Cs5t3lvoFKLScrO9Cr4ZLozVcnZZO1lmYa1rba2ik&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJuEXmTSKR9l58eXylbu8B1sjphPPZSH1M5BMYmwVrVaUergeQa7XfcG6rKZk&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfLYoc2UQY1H-T6pDlPbAJ7J-_c5vxTdBLuMToBJRIM83bYkwLfUBzTW9VPHg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTagma-A-PkMPXrzZbn5akRb2lTiiBJSRRHDkDEgtKrddZbNAxXwpTGwXLvwD8&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREwNquXDh140ZPfBZqic6UUaF_Zc2rP0uS7CGza4Tc_kxKRk_KcBFtOz5N34s&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAshGYy92moeLcrytmHFSKPHoGlDY96jvPtlwr9IiPT2w_khY0dejiqNNxfE4&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTOmkhPMLji4vd57r61axnTO1aysrz-7Wuv7-yUgBH010qK4I_Hiot6OGc3SQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR6hEK9wtKaufK1kPa3i9Sv1J8iv_s-M5u3XV4CImyeU0q7S8BWqkq-donvvAw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSa46pTRL7abCjmPPu1vuE70VAlT7zly5qLmFUdZO6opVTOr39_pSwnhXGofGM&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKRZjVWjcivGVgLh7IDewmQMMFcuimhpmWFRm4MlE5qhqjtfsoB3Ve2q_0bw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXuOAPnwBljHc6cR_94ZBUkbWAewaJdb5_XOJRu2tS6Af1wC38jbdwcL-HJjE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6CIQH86FNl4J6TJRyQjlX0F3XldvnWeypFGs1RyRDE_dMgwXpgepOFmNfRKo&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRYjQZkydIul1RRPhThgrTWAqKvar5UTJbSnqmUwpZrLDnte-pqJOd2-TNAzEs&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFOM6qr_ExBaBkQGPd08kqe4Gy_X6NBhIw_darV8KEVfRnhZZxEWUlz2xXNg4&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQEDtCLef6iEzrAyjaiZiIDWJ9MEo-EHHCufwV8IF_y18x7OnFHvhU0jKmz_vY&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHp0ve2WPF1i3zx_qV101x5O02kjKKkr_iD-sJ43WMcaa5ObEROrtu8VzfVoE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdurFOqrSLe1EoVXwvxumBz4qBQhzLXXTfUeQFyJ6xMyWGcmOC_RmvRYXscLs&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDZSdGrho352ojW-ZxZbYekzJANuZ7DDvXQ08wKIz7BSpTomC-ku1sCjkKTg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1ISWmvXtJ0i6nRKyCt7Hg45h5ry1MuxQzMRrfMZ7rtz5giy1aHf6_X3KmC4s&s']

# %%
image_source=[image for image in image_source if image.startswith('https')]
image_source
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFhiWD9Bp7SXM_HP8_TlWzuvs7MF-mPYa7LV0h8Q7Gy6ii7TjuJikwKWaZTOE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDvO0ky2gO_nenMQVae5Cs5t3lvoFKLScrO9Cr4ZLozVcnZZO1lmYa1rba2ik&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJuEXmTSKR9l58eXylbu8B1sjphPPZSH1M5BMYmwVrVaUergeQa7XfcG6rKZk&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfLYoc2UQY1H-T6pDlPbAJ7J-_c5vxTdBLuMToBJRIM83bYkwLfUBzTW9VPHg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTagma-A-PkMPXrzZbn5akRb2lTiiBJSRRHDkDEgtKrddZbNAxXwpTGwXLvwD8&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREwNquXDh140ZPfBZqic6UUaF_Zc2rP0uS7CGza4Tc_kxKRk_KcBFtOz5N34s&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAshGYy92moeLcrytmHFSKPHoGlDY96jvPtlwr9IiPT2w_khY0dejiqNNxfE4&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTOmkhPMLji4vd57r61axnTO1aysrz-7Wuv7-yUgBH010qK4I_Hiot6OGc3SQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR6hEK9wtKaufK1kPa3i9Sv1J8iv_s-M5u3XV4CImyeU0q7S8BWqkq-donvvAw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSa46pTRL7abCjmPPu1vuE70VAlT7zly5qLmFUdZO6opVTOr39_pSwnhXGofGM&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKRZjVWjcivGVgLh7IDewmQMMFcuimhpmWFRm4MlE5qhqjtfsoB3Ve2q_0bw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXuOAPnwBljHc6cR_94ZBUkbWAewaJdb5_XOJRu2tS6Af1wC38jbdwcL-HJjE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6CIQH86FNl4J6TJRyQjlX0F3XldvnWeypFGs1RyRDE_dMgwXpgepOFmNfRKo&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRYjQZkydIul1RRPhThgrTWAqKvar5UTJbSnqmUwpZrLDnte-pqJOd2-TNAzEs&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFOM6qr_ExBaBkQGPd08kqe4Gy_X6NBhIw_darV8KEVfRnhZZxEWUlz2xXNg4&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQEDtCLef6iEzrAyjaiZiIDWJ9MEo-EHHCufwV8IF_y18x7OnFHvhU0jKmz_vY&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHp0ve2WPF1i3zx_qV101x5O02kjKKkr_iD-sJ43WMcaa5ObEROrtu8VzfVoE&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdurFOqrSLe1EoVXwvxumBz4qBQhzLXXTfUeQFyJ6xMyWGcmOC_RmvRYXscLs&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDZSdGrho352ojW-ZxZbYekzJANuZ7DDvXQ08wKIz7BSpTomC-ku1sCjkKTg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1ISWmvXtJ0i6nRKyCt7Hg45h5ry1MuxQzMRrfMZ7rtz5giy1aHf6_X3KmC4s&s']

# %%
import wget
import os

# %%
# !mkdir dog

# %%
path='/content/dog'

# %%
c=0

for image in image_source:
  save_as = os.path.join(path, search_term + str(c) + '.jpg')
  wget.download(image, save_as)
  c += 1
